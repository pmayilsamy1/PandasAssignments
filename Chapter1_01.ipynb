# %% [markdown]
# <a href="https://colab.research.google.com/github/pmayilsamy1/PandasAssignments/blob/main/Chapter1_01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random
import pandas as pd
Store1 = pd.read_csv('/content/Datasets/Store1.csv')
Store1.head()
# Out:
#   Months  Grocery_sales  Stationary_sales
# 0    Jan             16                57
# 1    Jan             44               139
# 2    Jan             15                85
# 3    Jan             59                 8
# 4    Jan             36               106

# %%
Store2 = pd.read_csv('/content/Datasets/Store2.csv')
Store2.head()
# Out:
#   Months  Grocery_sales  Stationary_sales
# 0    Jan             36                84
# 1    Jan             51                63
# 2    Jan             17                71
# 3    Jan             48                65
# 4    Jan             57                66

# %%
Sales_store1 = (Store1[['Grocery_sales','Stationary_sales']].sum(axis=1)).sum()
Sales_store1
# Out:
# 6082

# %%
Sales_store2 = (Store2[['Grocery_sales','Stationary_sales']].sum(axis=1)).sum()
Sales_store2
# Out:
# 5847

# %%
Sales_store1 = Store1['Grocery_sales'].sum()
Sales_store1
# Out:
# 2097

# %%
Sales_store2 = Store2['Grocery_sales'].sum()
Sales_store2
# Out:
# 2696

# %%
Sales_store1 = Store1.groupby(['Months'])[['Grocery_sales','Stationary_sales']].agg('sum').agg('sum',axis = 1)
Sales_store1
# Out:
# Months
# Feb    1744
# Jan    1467
# Mar    2871
# dtype: int64

# %%
Sales_store2 = Store2.groupby(['Months'])[['Grocery_sales','Stationary_sales']].agg('sum').agg('sum',axis = 1)
Sales_store2
# Out:
# Months
# Feb    2050
# Jan    1419
# Mar    2378
# dtype: int64

# %%
Store1_stationary_greater = Store1[Store1['Stationary_sales'].gt(Store2['Stationary_sales'],axis=0)]
Store1_stationary_greater
# Out:
# <ipython-input-14-eead5dab1096>:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   Store1_stationary_greater = Store1[Store1['Stationary_sales'].gt(Store2['Stationary_sales'],axis=0)]
#    Months  Grocery_sales  Stationary_sales
# 1     Jan             44               139
# 2     Jan             15                85
# 4     Jan             36               106
# 5     Jan             27               136
# 6     Jan             74               116
# 7     Jan             63               142
# 8     Jan             65               129
# 9     Jan             12               138
# 10    Feb             34               112
# 11    Feb             73               100
# 12    Feb             45               135
# 13    Feb             31                13
# 14    Feb             61                51
# 16    Feb             20               141
# 17    Feb             18                72
# 18    Feb             60               134
# 19    Feb             62                47
# 21    Feb             25                75
# 23    Feb             10               118
# 25    Mar             72                97
# 26    Mar             48                63
# 27    Mar             64                54
# 28    Mar             14                78
# 29    Mar             51               104
# 30    Mar             30               133
# 33    Mar             66                80
# 35    Mar             54               111
# 36    Mar             46               147
# 37    Mar             43               137
# 39    Mar             55                50
# 42    Mar             28                73
# 44    Mar             57               124
# 46    Mar             11                86
# 48    Mar             52                68
# 49    Mar             29               113

# %%
len(Store1_stationary_greater)
# Out:
# 35
