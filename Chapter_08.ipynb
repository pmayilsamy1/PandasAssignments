# %% [markdown]
# <a href="https://colab.research.google.com/github/pmayilsamy1/PandasAssignments/blob/main/Chapter_08.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
file_url = '/content/data/titanic.csv'
data_frame = pd.read_csv(file_url)

# %%
data_frame.head()
# Out:
#    survived  ticket_class  gender   age  number_sibling_spouse  \
# 0         0             3    male  22.0                      1
# 1         1             1  female  38.0                      1
# 2         1             3  female  26.0                      0
# 3         1             1  female  35.0                      1
# 4         0             3    male  35.0                      0
#
#    number_parent_children  passenger_fare port_of_embarkation age_group
# 0                       0          7.2500                   S     18-59
# 1                       0         71.2833                   C     18-59
# 2                       0          7.9250                   S     18-59
# 3                       0         53.1000                   S     18-59
# 4                       0          8.0500                   S     18-59

# %%
data_frame = data_frame.dropna()
data_frame
# Out:
#      survived  ticket_class  gender   age  number_sibling_spouse  \
# 0           0             3    male  22.0                      1
# 1           1             1  female  38.0                      1
# 2           1             3  female  26.0                      0
# 3           1             1  female  35.0                      1
# 4           0             3    male  35.0                      0
# ..        ...           ...     ...   ...                    ...
# 885         0             3  female  39.0                      0
# 886         0             2    male  27.0                      0
# 887         1             1  female  19.0                      0
# 889         1             1    male  26.0                      0
# 890         0             3    male  32.0                      0
#
#      number_parent_children  passenger_fare port_of_embarkation age_group
# 0                         0          7.2500                   S     18-59
# ...

# %%
data_frame.age.plot(kind = 'hist');

# %%
data_frame.loc[data_frame['survived'] == 1].age.plot(kind = 'hist');
